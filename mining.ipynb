# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Load cleaned Excel data
df = pd.read_excel("bitre_fatalities_dec2024.xlsx", sheet_name="BITRE_Fatality", header=4)
df = df.replace("-9", "Unknown").fillna("Unknown")

# Select relevant categorical columns
selected_columns = [
    "Crash Type", "Gender", "Age Group", "Time of day",
    "Christmas Period", "Easter Period", "National Road Type",
    "Bus Involvement", "Road User"
]

df_arm = df[selected_columns]

# Convert rows into transactions like ["Crash Type=Single", "Gender=Male", ...]
transactions = df_arm.apply(lambda row: [f"{col}={row[col]}" for col in df_arm.columns], axis=1).tolist()

# One-hot encode transactions
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# Generate frequent itemsets
frequent_itemsets = apriori(df_encoded, min_support=0.02, use_colnames=True)

# Generate rules with confidence and lift
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# Filter for rules where "Road User=..." is in the consequent (RHS)
road_user_rules = rules[rules['consequents'].apply(lambda x: any("Road User=" in item for item in x))]

# Rank by lift and confidence
top_rules = road_user_rules.sort_values(by=["lift", "confidence"], ascending=False)

# Display top rules
top_rules.head(10)
# Out:
#                                              antecedents  \
# 38043  (Age Group=75_or_older, National Road Type=Und...
# 38037  (Age Group=75_or_older, National Road Type=Und...
# 26515  (Age Group=75_or_older, National Road Type=Und...
# 27136  (Age Group=75_or_older, National Road Type=Und...
# 38036  (Age Group=75_or_older, National Road Type=Und...
# 27131  (Age Group=75_or_older, National Road Type=Und...
# 26919  (Age Group=75_or_older, National Road Type=Und...
# 13580  (Age Group=75_or_older, National Road Type=Und...
# 38024  (Christmas Period=No, Easter Period=No, Nation...
# 26510  (Age Group=75_or_older, National Road Type=Und...
#
#                                              consequents  antecedent support  \
# 38043  (Road User=Pedestrian, Bus Involvement=No, Eas...            0.038383
# 38037  (Road User=Pedestrian, Bus Involvement=No, Chr...            0.038260
# 26515  (Road User=Pedestrian, Bus Involvement=No, Chr...            0.038383
# 27136  (Road User=Pedestrian, Easter Period=No, Chris...            0.038383
# 38036  (Road User=Pedestrian, Bus Involvement=No, Eas...            0.037592
# 27131        (Road User=Pedestrian, Christmas Period=No)            0.038260
# 26919  (Road User=Pedestrian, Bus Involvement=No, Eas...            0.038383
# 13580        (Road User=Pedestrian, Christmas Period=No)            0.038383
# 38024         (Road User=Pedestrian, Bus Involvement=No)            0.037469
# 26510         (Road User=Pedestrian, Bus Involvement=No)            0.037592
#
#        consequent support   support  confidence      lift  representativity  \
# 38043            0.144249  0.022699    0.591388  4.099781               1.0
# 38037            0.145075  0.022699    0.593290  4.089541               1.0
# 26515            0.145075  0.022770    0.593220  4.089058               1.0
# 27136            0.149277  0.023385    0.609253  4.081351               1.0
# 38036            0.148064  0.022699    0.603835  4.078201               1.0
# 27131            0.150104  0.023385    0.611213  4.071939               1.0
# 26919            0.148064  0.023139    0.602840  4.071480               1.0
# 13580            0.150104  0.023455    0.611086  4.071089               1.0
# 38024            0.148891  0.022699    0.605819  4.068888               1.0
# 26510            0.148891  0.022770    0.605706  4.068132               1.0
#
#        leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 38043  0.017163    2.094288       0.786264  0.141931   0.522511    0.374375
# 38037  0.017149    2.102053       0.785528  0.141309   0.524275    0.374878
# 26515  0.017201    2.101690       0.785599  0.141700   0.524193    0.375086
# 27136  0.017655    2.177172       0.785118  0.142353   0.540689    0.382954
# 38036  0.017133    2.150459       0.784276  0.139297   0.534983    0.378571
# 27131  0.017642    2.186022       0.784429  0.141746   0.542548    0.383503
# 26919  0.017456    2.145070       0.784501  0.141688   0.533815    0.379558
# 13580  0.017694    2.185305       0.784476  0.142127   0.542398    0.383673
# 38024  0.017121    2.159184       0.783593  0.138698   0.536862    0.379138
# 26510  0.017173    2.158567       0.783646  0.139083   0.536730    0.379317
